# %% [markdown]
# # 0. Importando bibliotecas

# %%
# Bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Reconhecendo e manipulando dados

# %% [markdown]
# ### 1.1 Tabelas dimensão

# %%
# d_Hospede.csv
df_hospede = pd.read_csv('d_hospede.csv')
df_hospede.head()
# Out:
#    hospede_id    pais  uf          cidade faixa_etaria segmento
# 0           1  Brasil  CE       Fortaleza        46-60     Corp
# 1           2  Brasil  RJ         Niterói        36-45    Lazer
# 2           3  Brasil  MG  Belo Horizonte        26-35    Lazer
# 3           4  Brasil  DF        Brasília        26-35    Lazer
# 4           5  Brasil  ES         Vitória        26-35    Lazer

# %%
# duplicada

df_hospede.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# d_hospede.csv não possui valores nulos ou valores duplicados.

# %%
# d_hotel.csv 
df_hotel = pd.read_csv('d_hotel.csv')
df_hotel
# Out:
#    hotel_id             nome          cidade  uf  categoria_estrelas  \
# 0         1  Nara Copacabana  Rio de Janeiro  RJ                   4
# 1         2    Nara Paulista       São Paulo  SP                   4
# 2         3     Nara Savassi  Belo Horizonte  MG                   3
# 3         4       Nara Barra        Salvador  BA                   4
# 4         5       Nara Batel        Curitiba  PR                   3
# 5         6    Nara Meireles       Fortaleza  CE                   5
#
#    possui_spa_flag
# 0                1
# 1                0
# 2                0
# 3                1
# 4                0
# 5                1

# %%
df_hotel.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_hotel.isna().sum()
# Out:
# hotel_id              0
# nome                  0
# cidade                0
# uf                    0
# categoria_estrelas    0
# possui_spa_flag       0
# dtype: int64

# %% [markdown]
# d_hotel.csv não possui valores nulos ou valores duplicados.

# %%
# d_motivo_cancelamento.csv
df_cancelamento = pd.read_csv('d_motivo_cancelamento.csv')
df_cancelamento.head()
# Out:
#    motivo_id              categoria                   descricao
# 0          1                  Preço     Encontrou tarifa melhor
# 1          2      Mudança de planos         Alteração de agenda
# 2          3  Problema de pagamento             Cartão recusado
# 3          4             Transporte  Cancelamento de voo/ônibus
# 4          5                 Outros        Motivo não informado

# %%
df_cancelamento.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_cancelamento.isna().sum()
# Out:
# motivo_id    0
# categoria    0
# descricao    0
# dtype: int64

# %% [markdown]
# d_motivo_cancelamento.csv não possui valores nulos ou valores duplicados.

# %%
# d_plano_tarifario
df_plano_tarifario = pd.read_csv('d_plano_tarifario.csv')
df_plano_tarifario.head()
# Out:
#    rate_plan_id               nome_plano  reembolsavel_flag  \
# 0             1  Flexível (Reembolsável)                  1
# 1             2         Não Reembolsável                  0
# 2             3         Corporativo Flex                  1
# 3             4     Pacote Fim de Semana                  0
# 4             5         Promo Antecipada                  0
#
#    cafe_incluso_flag              politica_cancelamento
# 0                  1  Cancelamento grátis até 48h antes
# 1                  0                      Sem reembolso
# 2                  1  Cancelamento grátis até 24h antes
# 3                  1                      Sem reembolso
# 4                  0                      Sem reembolso

# %%
df_plano_tarifario.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_plano_tarifario.isna().sum()
# Out:
# rate_plan_id             0
# nome_plano               0
# reembolsavel_flag        0
# cafe_incluso_flag        0
# politica_cancelamento    0
# dtype: int64

# %% [markdown]
# d_plano_tarifario.csv não possui valores nulos ou valores duplicados.

# %%
# d_agencia.csv
df_agencia = pd.read_csv('d_agencia.csv')
df_agencia.head()
# Out:
#    agencia_id     nome     tipo  comissao_pct
# 0           1  Booking      OTA          0.15
# 1           2  Decolar      OTA          0.17
# 2           3      CVC  Agência          0.12
# 3           4  FlyTour  Agência          0.10

# %%
df_agencia.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_agencia.isna().sum()
# Out:
# agencia_id      0
# nome            0
# tipo            0
# comissao_pct    0
# dtype: int64

# %% [markdown]
# d_agencia.csv não possui valores nulos ou valores duplicados.

# %%
# d_canal.csv
df_canal = pd.read_csv('d_canal.csv')
df_canal.head(6)
# Out:
#    canal_id      canal_nome canal_grupo
# 0         1   Direto - Site      Direto
# 1         2    Direto - App      Direto
# 2         3   OTA - Booking         OTA
# 3         4   OTA - Decolar         OTA
# 4         5     Corporativo        Corp
# 5         6  Agência Física     Agência

# %%
df_canal.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_canal.isna().sum()
# Out:
# canal_id       0
# canal_nome     0
# canal_grupo    0
# dtype: int64

# %% [markdown]
# d_canal.csv não possui valores nulos ou valores duplicados.

# %%
# d_data.csv
df_data = pd.read_csv('d_data.csv')
df_data.head()
# Out:
#     data_id        data   ano  mes nome_mes  trimestre  dia_semana  \
# 0  20240101  2024-01-01  2024    1      Jan          1           1
# 1  20240102  2024-01-02  2024    1      Jan          1           2
# 2  20240103  2024-01-03  2024    1      Jan          1           3
# 3  20240104  2024-01-04  2024    1      Jan          1           4
# 4  20240105  2024-01-05  2024    1      Jan          1           5
#
#    fim_de_semana_flag  feriado_flag  alta_temporada_flag
# 0                   0             1                    1
# 1                   0             0                    1
# 2                   0             0                    1
# 3                   0             0                    1
# 4                   0             0                    1

# %%
df_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_data.isna().sum()
# Out:
# data_id                0
# data                   0
# ano                    0
# mes                    0
# nome_mes               0
# trimestre              0
# dia_semana             0
# fim_de_semana_flag     0
# feriado_flag           0
# alta_temporada_flag    0
# dtype: int64

# %% [markdown]
# d_data.csv não possui valores nulos ou valores duplicados.

# %%
# d_tipo_quarto.csv
df_quarto = pd.read_csv('d_tipo_quarto.csv')
df_quarto
# Out:
#    tipo_quarto_id tipo_quarto  capacidade
# 0               1    Standard           2
# 1               2    Superior           2
# 2               3      Deluxe           3
# 3               4       Suite           3
# 4               5     Familia           4

# %%
df_quarto.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_quarto.isnull().sum()
# Out:
# tipo_quarto_id    0
# tipo_quarto       0
# capacidade        0
# dtype: int64

# %% [markdown]
# d_tipo_quarto.csv não possui valores nulos ou valores duplicados.

# %% [markdown]
# ### 1.2 Tabelas fato

# %%
# f_diarias.csv
df_diaria = pd.read_csv('f_diarias.csv')
df_diaria.head()
# Out:
#    hotel_id   data_id tipo_quarto  quartos_vendidos  adr_estimado  \
# 0         1  20240101    Standard                37        367.51
# 1         1  20240102    Standard                39        424.36
# 2         1  20240103    Standard                32        350.25
# 3         1  20240104    Standard                35        309.44
# 4         1  20240105    Standard                54        332.37
#
#    receita_diarias
# 0         13597.84
# 1         16549.95
# 2         11207.86
# 3         10830.30
# 4         17948.08

# %%
df_diaria.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_diaria.isna().sum()
# Out:
# hotel_id            0
# data_id             0
# tipo_quarto         0
# quartos_vendidos    0
# adr_estimado        0
# receita_diarias     0
# dtype: int64

# %%
df_diaria.loc[df_diaria['receita_diarias'] < 0]
# Out:
#        hotel_id   data_id tipo_quarto  quartos_vendidos  adr_estimado  \
# 1142          1  20250215    Superior                27        376.42
# 1386          1  20251017    Superior                23        398.99
# 2406          1  20240801       Suite                 7        730.69
# 4229          2  20250728    Standard                40        295.43
# 5194          2  20240318      Deluxe                15        429.01
# 5931          2  20240324       Suite                 6        540.39
# 5945          2  20240407       Suite                 7        932.03
# 6711          2  20240512     Familia                 7        682.30
# 7932          3  20250914    Standard                34        280.67
# 8347          3  20241102    Superior                27        330.86
# 9397          3  20250917      Deluxe                 8        502.68
# 9687          3  20240703       Suite                 4        722.36
# ...

# %%
# Removendo da tabela as linhas na receita diária é negativa (absurdo)
df_diaria_novo = df_diaria.loc[df_diaria['receita_diarias'] > 0]
df_diaria_novo
# Out:
#        hotel_id   data_id tipo_quarto  quartos_vendidos  adr_estimado  \
# 0             1  20240101    Standard                37        367.51
# 1             1  20240102    Standard                39        424.36
# 2             1  20240103    Standard                32        350.25
# 3             1  20240104    Standard                35        309.44
# 4             1  20240105    Standard                54        332.37
# ...         ...       ...         ...               ...           ...
# 21925         6  20251227     Familia                14        763.34
# 21926         6  20251228     Familia                16        709.42
# 21927         6  20251229     Familia                14        644.95
# 21928         6  20251230     Familia                13        869.08
# 21929         6  20251231     Familia                14        748.11
#
#        receita_diarias
# 0             13597.84
# 1             16549.95
# 2             11207.86
# 3             10830.30
# ...

# %%
#Gerando uma nova tabela com os dados tratados
df_diaria_novo.to_csv('f_diarianovo.csv', sep = ';', index=False)

# %% [markdown]
# f_diarias.csv não possui valores nulos ou valores duplicados, porém haviam valores inconclusivos que foram removidos.

# %%
# f_reservas.csv
df_reserva = pd.read_csv('f_reservas.csv')
df_reserva.head()
# Out:
#    reserva_id  data_reserva_id  data_cancelamento_id  motivo_cancelamento_id  \
# 0           1         20240229                   NaN                     NaN
# 1           2         20250522            20250610.0                     2.0
# 2           3         20241209                   NaN                     NaN
# 3           4         20250306                   NaN                     NaN
# 4           5         20240423            20240504.0                     2.0
#
#    checkin_id  checkout_id  hotel_id  hospede_id  canal_id  agencia_id  \
# 0    20240301     20240302         5       10394         1         NaN
# 1    20250622     20250625         5       10147         4         2.0
# 2    20241228     20241229         5       11484         1         NaN
# 3    20250323     20250324         2        7030         2         NaN
# 4    20240527     20240528         5        4216         1         NaN
#
# ...

# %%
df_reserva.duplicated().sum()
# Out:
# np.int64(80)

# %%
df_reserva.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of        reserva_id  data_reserva_id  data_cancelamento_id  \
# 0               1         20240229                   NaN
# 1               2         20250522            20250610.0
# 2               3         20241209                   NaN
# 3               4         20250306                   NaN
# 4               5         20240423            20240504.0
# ...           ...              ...                   ...
# 32075        2684         20240118                   NaN
# 32076       21255         20240724                   NaN
# 32077       25301         20240529                   NaN
# 32078       10869         20250228            20250305.0
# 32079       15432         20240523            20240524.0
#
#        motivo_cancelamento_id  checkin_id  checkout_id  hotel_id  hospede_id  \
# 0                         NaN    20240301     20240302         5       10394
# 1                         2.0    20250622     20250625         5       10147
# ...

# %%
df_reserva.to_csv('f_reservanovo.csv', sep = ';', index=False)

# %% [markdown]
# f_reservas.csv possuia valores nulos válidos, e valores duplicados, o quais foram removidos.

# %%
# f_pagamentos.csv
df_pagamentos = pd.read_csv('f_pagamentos.csv')
df_pagamentos.head()
# Out:
#    pagamento_id  reserva_id  data_pagamento_id forma_pagamento  valor_pago  \
# 0             1           1           20240224         Crédito      892.93
# 1             2           3           20241225         Crédito      218.23
# 2             3           3           20241226         Crédito      224.66
# 3             4           4           20250319             PIX      263.71
# 4             5           6           20240404         Crédito     3415.63
#
#   status_pagamento  taxa_gateway
# 0         Aprovado         25.00
# 1        Estornado          6.11
# 2         Aprovado          6.29
# 3         Aprovado          3.16
# 4         Aprovado         95.64

# %%
df_pagamentos.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_pagamentos.isna().sum()
# Out:
# pagamento_id         0
# reserva_id           0
# data_pagamento_id    0
# forma_pagamento      0
# valor_pago           0
# status_pagamento     0
# taxa_gateway         0
# dtype: int64

# %% [markdown]
# f_pagamentos.csv não possui valores nulos ou valores duplicados.

# %%
# f_inventario_diario.csv
df_inventariodiario = pd.read_csv('f_inventario_diario.csv')
df_inventariodiario.head()
# Out:
#    hotel_id   data_id tipo_quarto  quartos_total  quartos_manutencao  \
# 0         1  20240101    Standard             55                   2
# 1         1  20240102    Standard             55                   2
# 2         1  20240103    Standard             55                   0
# 3         1  20240104    Standard             55                   1
# 4         1  20240105    Standard             55                   0
#
#    quartos_disponiveis
# 0                   53
# 1                   53
# 2                   55
# 3                   54
# 4                   55

# %%
df_inventariodiario.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_inventariodiario.isna().sum()
# Out:
# hotel_id               0
# data_id                0
# tipo_quarto            0
# quartos_total          0
# quartos_manutencao     0
# quartos_disponiveis    0
# dtype: int64

# %% [markdown]
# f_inventario_diario.csv não possui valores nulos ou valores duplicados.

# %%
df_review = pd.read_csv('f_reviews.csv')
df_review.head()
# Out:
#    review_id  reserva_id  data_review_id  nota  limpeza  localizacao  \
# 0          1        4081        20240528   7.7      7.3          8.5
# 1          2        1095        20250816   9.0      8.8          8.6
# 2          3       12895        20250320   8.6      7.8          9.0
# 3          4       25185        20251017   6.4      6.2          5.9
# 4          5       13176        20241128   8.9      9.3          9.4
#
#    atendimento  comentario_flag
# 0          7.9                0
# 1          7.4                0
# 2          9.5                1
# 3          6.5                0
# 4          8.5                0

# %%
df_review.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_review.isna().sum()
# Out:
# review_id          0
# reserva_id         0
# data_review_id     0
# nota               0
# limpeza            0
# localizacao        0
# atendimento        0
# comentario_flag    0
# dtype: int64

# %%
#Verificando se há notas fora do intervalo válido [0,10]
df_review.loc[(df_review['nota'] > 10) | (df_review['nota'] < 0)]
# Out:
#       review_id  reserva_id  data_review_id  nota  limpeza  localizacao  \
# 2272       2273       19799        20240930  11.0      9.3          9.5
# 2476       2477       20089        20241220  11.0     10.0         10.0
# 2923       2924       25900        20251024  11.0      6.1          6.9
# 3541       3542       29229        20241122  11.0      8.4          7.4
# 3596       3597        5643        20240301  11.0      8.4          8.4
# 3963       3964        4334        20241208  11.0      6.9          7.7
# 6070       6071        9664        20251124  11.0      8.5          7.6
# 6428       6429       24249        20260120  11.0      7.0          7.5
# 6450       6451        7167        20250907  11.0      7.3          6.6
# 8108       8109       28574        20241026  11.0      8.8          8.9
# 8264       8265       10456        20240719  11.0      8.8          9.1
# 8265       8266          68        20251222  11.0      6.0          7.5
# ...

# %%
df_review_ratio = df_review.loc[(df_review['nota'].between(0,10)) | (df_review['limpeza'].between(0,10)) | (df_review['localizacao'].between(0,10)) | (df_review['atendimento'].between(0,10))]
df_review_ratio
# Out:
#        review_id  reserva_id  data_review_id  nota  limpeza  localizacao  \
# 0              1        4081        20240528   7.7      7.3          8.5
# 1              2        1095        20250816   9.0      8.8          8.6
# 2              3       12895        20250320   8.6      7.8          9.0
# 3              4       25185        20251017   6.4      6.2          5.9
# 4              5       13176        20241128   8.9      9.3          9.4
# ...          ...         ...             ...   ...      ...          ...
# 10767      10768        4983        20240425   7.7      7.6          8.0
# 10768      10769       31831        20240908   6.2      6.9          6.5
# 10769      10770        9662        20251225   5.4      5.7          5.7
# 10770      10771       22855        20250802   7.3      8.0          6.6
# 10771      10772       21865        20251031   9.1      9.3          8.1
#
#        atendimento  comentario_flag
# 0              7.9                0
# ...

# %%
df_review_ratio.to_csv('f_reviewsnovo.csv', sep=';', index=False)

# %% [markdown]
# f_reviews.csv não possui valores nulos ou valores duplicados, porém foi ajustado para que não houvessem notas fora do intervalo [0,10]

# %% [markdown]
# ---

# %% [markdown]
# # 2 Análise descritiva

# %% [markdown]
# ### 2.1 Analisando o valor previsto em reservas por hotel

# %%
# Valor_previsto total por hotel
df_reserva = pd.read_csv('f_reservanovo.csv', sep=';')
df_reserva
# Out:
#        reserva_id  data_reserva_id  data_cancelamento_id  \
# 0               1         20240229                   NaN
# 1               2         20250522            20250610.0
# 2               3         20241209                   NaN
# 3               4         20250306                   NaN
# 4               5         20240423            20240504.0
# ...           ...              ...                   ...
# 32075        2684         20240118                   NaN
# 32076       21255         20240724                   NaN
# 32077       25301         20240529                   NaN
# 32078       10869         20250228            20250305.0
# 32079       15432         20240523            20240524.0
#
#        motivo_cancelamento_id  checkin_id  checkout_id  hotel_id  hospede_id  \
# 0                         NaN    20240301     20240302         5       10394
# 1                         2.0    20250622     20250625         5       10147
# ...

# %%
# Unificando tabelas df_hotel e df_reserva
df_total_hotel = pd.merge(df_reserva, df_hotel, on='hotel_id', how='inner')
df_total_hotel
# Out:
#        reserva_id  data_reserva_id  data_cancelamento_id  \
# 0               1         20240229                   NaN
# 1               2         20250522            20250610.0
# 2               3         20241209                   NaN
# 3               4         20250306                   NaN
# 4               5         20240423            20240504.0
# ...           ...              ...                   ...
# 32075        2684         20240118                   NaN
# 32076       21255         20240724                   NaN
# 32077       25301         20240529                   NaN
# 32078       10869         20250228            20250305.0
# 32079       15432         20240523            20240524.0
#
#        motivo_cancelamento_id  checkin_id  checkout_id  hotel_id  hospede_id  \
# 0                         NaN    20240301     20240302         5       10394
# 1                         2.0    20250622     20250625         5       10147
# ...

# %%
# Verificando tipo de moedas
df_total_hotel['moeda'].unique()
# Out:
# <StringArray>
# ['BRL', 'USD', 'EUR']
# Length: 3, dtype: str

# %% [markdown]
# Como há pagamentos em outros tipos de moeda, será realizada a conversão para Reais(BRL) utilizando a seguinte taxa:
#
# Dólar(USD) = 5.30 BRL
#
# Euro(EUR) = 6.30 BRL
#
# (Cotação do dia 20/01/2026)

# %%
usd = 5.30
eur = 6.30
df_total_hotel['valor_previsto_corrigido'] = df_total_hotel['valor_previsto']
df_total_hotel.loc[df_total_hotel['moeda'] == 'USD', 'valor_previsto_corrigido'] = df_total_hotel['valor_previsto'] * usd
df_total_hotel.loc[df_total_hotel['moeda'] == 'EUR', 'valor_previsto_corrigido'] = df_total_hotel['valor_previsto'] * eur

# %%
# Criando tabela somente de diárias realizadas
df_total_hotel_finalizada = df_total_hotel.loc[df_total_hotel['status'] == 'Finalizada']
df_total_hotel_finalizada.head()
# Out:
#    reserva_id  data_reserva_id  data_cancelamento_id  motivo_cancelamento_id  \
# 0           1         20240229                   NaN                     NaN
# 2           3         20241209                   NaN                     NaN
# 3           4         20250306                   NaN                     NaN
# 5           6         20240326                   NaN                     NaN
# 6           7         20240812                   NaN                     NaN
#
#    checkin_id  checkout_id  hotel_id  hospede_id  canal_id  agencia_id  ...  \
# 0    20240301     20240302         5       10394         1         NaN  ...
# 2    20241228     20241229         5       11484         1         NaN  ...
# 3    20250323     20250324         2        7030         2         NaN  ...
# 5    20240404     20240414         1        6436         3         1.0  ...
# 6    20240819     20240822         3        1989         4         2.0  ...
#
# ...

# %%
plt.figure(figsize=(10,6))
receita_hoteis = df_total_hotel_finalizada.groupby('nome')['valor_previsto_corrigido'].sum().reset_index().sort_values(by= 'valor_previsto_corrigido', ascending=False)
sns.barplot(data=receita_hoteis, x= 'nome', y= 'valor_previsto_corrigido')
plt.title('Valor previsto por hotel (em Milhões)')
plt.ylabel('Valor previsto (em Reais)')
plt.xlabel('Hotel')
plt.show()

# %%
receita_hoteis
# Out:
#               nome  valor_previsto_corrigido
# 3    Nara Meireles               8462371.341
# 0       Nara Barra               7207342.372
# 2  Nara Copacabana               7169123.765
# 4    Nara Paulista               7071483.419
# 1       Nara Batel               6176548.023
# 5     Nara Savassi               6015231.699

# %% [markdown]
# De acordo com as análises, os Hotéis 'Nara Meireles', 'Nara Barra' e 'Nara Copacabana' foram os que geraram um maior valor previsto em reservas.

# %% [markdown]
# ----

# %% [markdown]
# ### 2.2 Analisando o maior motivo para cancelamentos

# %%
df_reserva['motivo_id'] = df_reserva['motivo_cancelamento_id']

# %%
# Analisano sobre motivos de cancelamento
df_reserva_cancelamento = pd.merge(df_reserva, df_cancelamento, on='motivo_id', how='inner')
df_reserva_cancelamento.head()
# Out:
#    reserva_id  data_reserva_id  data_cancelamento_id  motivo_cancelamento_id  \
# 0           2         20250522            20250610.0                     2.0
# 1           5         20240423            20240504.0                     2.0
# 2           8         20240221            20240229.0                     1.0
# 3           9         20241229            20250107.0                     2.0
# 4          15         20250113            20250113.0                     2.0
#
#    checkin_id  checkout_id  hotel_id  hospede_id  canal_id  agencia_id  ...  \
# 0    20250622     20250625         5       10147         4         2.0  ...
# 1    20240527     20240528         5        4216         1         NaN  ...
# 2    20240304     20240306         6        5123         1         NaN  ...
# 3    20250115     20250117         3        2167         5         NaN  ...
# 4    20250114     20250119         4        5745         4         2.0  ...
#
# ...

# %%
cancelamentos = df_reserva_cancelamento.groupby('categoria').size().reset_index(name='total').sort_values(by= 'total', ascending=False)

# %%
plt.figure(figsize=(10,5))
sns.barplot(data = cancelamentos, x='categoria', y='total')
plt.title('Cancelamentos por categoria')
plt.xlabel('Categoria')
plt.ylabel('Nº de cancelamentos')
plt.show()

# %%
cancelamentos
# Out:
#                categoria  total
# 0      Mudança de planos   2569
# 2                  Preço   1291
# 3  Problema de pagamento    663
# 4             Transporte    554
# 1                 Outros    545

# %% [markdown]
# A categoria com o maior número de cancelamentos é a "Mudança de planos".

# %% [markdown]
# ---

# %% [markdown]
# ### 2.3 Analisando quais agências convertem mais vendas

# %%
# Agencias que mais convertem
df_total_hotel['status'].unique()
# Out:
# <StringArray>
# ['Finalizada', 'Cancelada', 'No-show']
# Length: 3, dtype: str

# %%
agencia_reserva = pd.merge(df_total_hotel, df_agencia, on='agencia_id', how='inner')
agencia_reserva['nome_y']
# Out:
# 0        Decolar
# 1        Booking
# 2        Decolar
# 3            CVC
# 4        Decolar
#           ...
# 17828    FlyTour
# 17829    Booking
# 17830    Decolar
# 17831    Booking
# 17832        CVC
# Name: nome_y, Length: 17833, dtype: str

# %%
# Encontrando o total de reservas em cada agência
total_agencias = agencia_reserva.groupby('nome_y').size().reset_index(name='Total de reservas')
total_agencias
# Out:
#     nome_y  Total de reservas
# 0  Booking               8905
# 1      CVC               1595
# 2  Decolar               5751
# 3  FlyTour               1582

# %%
conversao = agencia_reserva.groupby(['nome_y','status']).size().reset_index(name='total')

# %%
# Diferenciando reservas de cada agência por status
status = ['Finalizada', 'Cancelada', 'No-show']
plt.figure(figsize=(10,5))
sns.barplot(data = conversao, x= 'nome_y', y= 'total', hue= 'status')
plt.title('Status de reservas por agência')
plt.xlabel('Agência')
plt.ylabel('Nº de reservas')
plt.show()

# %% [markdown]
# De acordo com a análises, temos que:
#
# As agências 'Booking', 'Decolar' e 'CVC' são as que mai convertem reservas e respectivamente as que mais possuem reservas finalizadas;
#
# O número de reservas finalizadas é proporcional ao número de reservas canceladas e no-show.

# %% [markdown]
# ---

# %% [markdown]
# ### 2.4 Analizando a sazonalidade de reservas

# %%
data_reserva = df_total_hotel.groupby('data_reserva_id').size().reset_index(name='total')
data_reserva['data_id'] = range(1, len(data_reserva) + 1)
data_reserva
# Out:
#      data_reserva_id  total  data_id
# 0           20240101     46        1
# 1           20240102     40        2
# 2           20240103     53        3
# 3           20240104     46        4
# 4           20240105     49        5
# ..               ...    ...      ...
# 726         20251227     45      727
# 727         20251228     42      728
# 728         20251229     44      729
# 729         20251230     52      730
# 730         20251231     42      731
#
# [731 rows x 3 columns]

# %%
# Sazonalidade ao longo de 2024
sazonalidade2024 = data_reserva.loc[(data_reserva['data_id'] >= 1) & (data_reserva['data_id'] <= 366)]
sazonalidade2024['total_suave'] = sazonalidade2024['total'].rolling(window=30).mean()
plt.Figure(figsize=(100,5))
sns.lineplot(sazonalidade2024, x='data_id', y='total_suave')
plt.title('Sazonalidade de 2024')
plt.xlabel('Dia do ano')
plt.ylabel('Quantidade de reservas')
plt.show()

# %%
# Sazonalidade ao longo de 2025
sazonalidade2025 = data_reserva.loc[(data_reserva['data_id'] >= 367) & (data_reserva['data_id'] <= 731)]
sazonalidade2025['total_suave'] = sazonalidade2025['total'].rolling(window=30).mean()
plt.Figure(figsize=(50,30))
sns.lineplot(sazonalidade2025, x='data_id', y='total_suave')
plt.title('Sazonalidade de 2025')
plt.xlabel('Dia do ano')
plt.ylabel('Quantidade de reservas')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 2.5 Analisando o quanto de receita diária é gerada pelos hoteis

# %%
df_diaria_novo.head()
# Out:
#    hotel_id   data_id tipo_quarto  quartos_vendidos  adr_estimado  \
# 0         1  20240101    Standard                37        367.51
# 1         1  20240102    Standard                39        424.36
# 2         1  20240103    Standard                32        350.25
# 3         1  20240104    Standard                35        309.44
# 4         1  20240105    Standard                54        332.37
#
#    receita_diarias
# 0         13597.84
# 1         16549.95
# 2         11207.86
# 3         10830.30
# 4         17948.08

# %%
# Calculando estatística descritiva da receita das diárias a partir do tipo de quarto
df_diaria_novo['tipo_quarto'].unique()
# Out:
# <StringArray>
# ['Standard', 'Superior', 'Deluxe', 'Suite', 'Familia']
# Length: 5, dtype: str

# %%
quartos = ['Standard', 'Superior', 'Deluxe', 'Suite', 'Familia']

# %%
for quarto in quartos:
    array_receita = np.array(df_diaria_novo['receita_diarias'].loc[df_diaria_novo['tipo_quarto'] == quarto])
    maximo = np.max(array_receita)
    minimo = np.min(array_receita)
    media = np.mean(array_receita)
    mediana = np.median(array_receita)
    q1 = np.quantile(array_receita, 0.25)
    q3 = np.quantile(array_receita, 0.75)
    iqr = q3 - q1
    ls = q3 + iqr*1.5
    li = q1 - iqr*1.5
    outliersuperior = df_diaria_novo['receita_diarias'].loc[(df_diaria_novo['tipo_quarto'] == quarto) & (df_diaria_novo['receita_diarias'] > ls)]
    outlierinferior = df_diaria_novo['receita_diarias'].loc[(df_diaria_novo['tipo_quarto'] == quarto) & (df_diaria_novo['receita_diarias'] < li)]
    print(f'------------Informações: Quarto tipo {quarto}------------')
    print(f'A maior receita diária foi: {maximo:.2f} Reais.')
    print(f'A menor receita diária foi: {minimo:.2f} Reais.')
    print(f'A receita diária média foi: {media:.2f} Reais.')
    print(f'A mediana da receita diária é: {mediana:.2f} Reais.')
    print(f'25% da receita diária está em: {q1:.2f} Reais.')
    print(f'75% da receita diária está em: {q3:.2f} Reais.')
    print(f'Há {len(outliersuperior)} dias que o quarto do tipo {quarto} arrecadou acima da média de receita diária (outlier superior)')
    print(f'Há {len(outlierinferior)} dias que o quarto do tipo {quarto} arrecadou abaixo da média de receita diária (outlier inferior)')
    print('')
# Out:
# ------------Informações: Quarto tipo Standard------------
# A maior receita diária foi: 129003.06 Reais.
# A menor receita diária foi: 3428.32 Reais.
# A receita diária média foi: 12215.19 Reais.
# A mediana da receita diária é: 11198.52 Reais.
# 25% da receita diária está em: 8561.39 Reais.
# 75% da receita diária está em: 14835.86 Reais.
# Há 105 dias que o quarto do tipo Standard arrecadou acima da média de receita diária (outlier superior)
# Há 0 dias que o quarto do tipo Standard arrecadou abaixo da média de receita diária (outlier inferior)
#
# ------------Informações: Quarto tipo Superior------------
# A maior receita diária foi: 90993.01 Reais.
# A menor receita diária foi: 2802.53 Reais.
# A receita diária média foi: 10161.03 Reais.
# A mediana da receita diária é: 9276.99 Reais.
# 25% da receita diária está em: 7045.37 Reais.
# 75% da receita diária está em: 12224.86 Reais.
# ...

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df_diaria_novo, x='tipo_quarto', y='receita_diarias', order = quartos)
plt.title('Distribuição de Receita das diárias por Tipo de Quarto reservado')
plt.xlabel('Receita das diárias')
plt.ylabel('Tipo de Quarto')
plt.ylim(400, 25000)
plt.show()

# %% [markdown]
# ### 2.6 Analisando correlação entre as notas de limpeza, localização e atendimento à nota final

# %%
df_reserva_novo = pd.read_csv('f_reservanovo.csv', sep=';')
df_nota_reserva = pd.merge(df_review_ratio, df_reserva_novo, on='reserva_id', how='inner')
df_nota_reserva
# Out:
#        review_id  reserva_id  data_review_id  nota  limpeza  localizacao  \
# 0              1        4081        20240528   7.7      7.3          8.5
# 1              2        1095        20250816   9.0      8.8          8.6
# 2              3       12895        20250320   8.6      7.8          9.0
# 3              4       25185        20251017   6.4      6.2          5.9
# 4              5       13176        20241128   8.9      9.3          9.4
# ...          ...         ...             ...   ...      ...          ...
# 10798      10768        4983        20240425   7.7      7.6          8.0
# 10799      10769       31831        20240908   6.2      6.9          6.5
# 10800      10770        9662        20251225   5.4      5.7          5.7
# 10801      10771       22855        20250802   7.3      8.0          6.6
# 10802      10772       21865        20251031   9.1      9.3          8.1
#
#        atendimento  comentario_flag  data_reserva_id  data_cancelamento_id  \
# ...

# %%
# Calculando correlação entre nota final e nota de limpeza
plt.figure(figsize=(20,10))
sns.lmplot(data=df_nota_reserva, x='limpeza', y='nota')
plt.show()
x = np.array(df_nota_reserva['limpeza'])
y = np.array(df_nota_reserva['nota'])
correlacao = np.corrcoef(x, y)
coef = correlacao[0,1]
print(coef)
# Out:
# 0.8209807268351463

# %% [markdown]
# Com o índice de correlação corrigido igual a 0,82, podemos afirmar que há uma forte correlação entre a nota da limpeza e a nota final.

# %%
# Calculando correlação entre nota final e nota de atendimento
plt.figure(figsize=(20,10))
sns.lmplot(data=df_nota_reserva, x='atendimento', y='nota')
plt.show()
x = np.array(df_nota_reserva['atendimento'])
correlacao = np.corrcoef(x, y)
coef = correlacao[0,1]
print(coef)
# Out:
# 0.7829241278401443

# %% [markdown]
# Com o índice de correlação corrigido igual a 0,78, podemos afirmar que há uma forte correlação entre a nota de atendimento e a nota final.

# %%
# Calculando correlação entre nota final e nota de localização
plt.figure(figsize=(20,10))
sns.lmplot(data=df_nota_reserva, x='localizacao', y='nota')
plt.show()
x = np.array(df_nota_reserva['localizacao'])
correlacao = np.corrcoef(x, y)
coef = correlacao[0,1]
print(coef)
# Out:
# 0.8542029864647736

# %% [markdown]
# Com o índice de correlação corrigido igual a 0,85, podemos afirmar que há uma forte correlação entre a nota de localização e a nota final.
